# %%
import sagemaker
import boto3
from sagemaker.huggingface import HuggingFace

role = 'arn:aws:iam::288347194123:role/god' # set up on AWS

'''
try:
	role = sagemaker.get_execution_role()
except ValueError:
	iam = boto3.client('iam')
	role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']
'''

hyperparameters = {
	'model_name_or_path':'meta-llama/Meta-Llama-3-70B-Instruct',
	'output_dir':'/opt/ml/model'
	# add your remaining hyperparameters
	# more info here https://github.com/huggingface/transformers/tree/v4.37.0/examples/pytorch/language-modeling
}

# git configuration to download our fine-tuning script
# THIS IS THE FUCKING PLACE TO EDIT THE VERSION YOU DUMB SHIT

git_config = {'repo': 'https://github.com/huggingface/transformers.git','branch': 'v4.40-release'}

# creates Hugging Face estimator
huggingface_estimator = HuggingFace(
	entry_point='run_clm.py',
	source_dir='./examples/pytorch/language-modeling',
	instance_type='ml.p3.2xlarge',
	instance_count=1,
	role=role,
	git_config=git_config,
	transformers_version='4.37.0',
	pytorch_version='2.1.0',
	py_version='py310',
	hyperparameters = hyperparameters
)

# starting the train job
huggingface_estimator.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 42
#      28 huggingface_estimator = HuggingFace(
#      29 	entry_point='run_clm.py',
#      30 	source_dir='./examples/pytorch/language-modeling',
#    (...)
#      38 	hyperparameters = hyperparameters
#      39 )
#      41 # starting the train job
# ---> 42 huggingface_estimator.fit()
#
# File ~/opt/anaconda3/envs/leetcode/lib/python3.11/site-packages/sagemaker/workflow/pipeline_context.py:346, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     342         return context
#     344     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 346 return run_func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/leetcode/lib/python3.11/site-packages/sagemaker/estimator.py:1340, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
# ...
